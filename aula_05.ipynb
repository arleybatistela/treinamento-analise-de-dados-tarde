# %% [markdown]
# # Relatório de análise de performance e hábitos de estudantes
# Relatorio criado durante o curso de Fundamentos de IA e Análide de dados
#
# ---
#
# >** Base fictícia open source **

# %% [markdown]
# Realizando as importações das bibliotecas necessárias para o projeto.

# %% [markdown]
# - A primeira linha de código usa a biblioteca pandas (importada como pd) para ler um arquivo CSV e carregá-lo em um dataframe — uma estrutura de dados tabular (linhas e colunas), parecida com uma planilha.
#
# - A segunda carrega a biblioteca Seaborn, que é uma biblioteca de visualização de dados em Python, construída sobre a Matplotlib. Ela é usada para criar gráficos estatísticos de forma mais simples e com visual mais agradável (cores, estilos, etc.) do que a Matplotlib "pura".

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# - df é a variável que guarda o dataset e o pd.readcsv está lendo o caminho dos dados.

# %%
df = pd.read_csv(r".\data\dataset_aula03_student_habits_performance.csv")

# %% [markdown]
# - df é uma variável que guarda o dataset.

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
#  - O comando head apresenta as 5 primeiras linhas do dataset.

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %% [markdown]
# - O Comando shape mostra o numero de linhas e colunas.

# %%
df.shape
# Out:
# (1000, 16)

# %% [markdown]
#  - O Comando tail mostra a "calda" as ultimas linhas da "tabela"

# %%
df.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %% [markdown]
# - O Comando info mostra tipos de dados e valores nulos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %% [markdown]
# - Conta quantos valores estão ausentes (nulos) na coluna parental_education_level do dataframe e exibe esse total em uma mensagem informando quantos dados desconhecidos existem sobre a escolaridade dos pais.

# %%
#Clean Code
valores_nulos = (df["parental_education_level"].isna().sum())
print(f"A coluna de escolaridade dos pais possui {valores_nulos} dados desconhecidos.")
# Out:
# A coluna de escolaridade dos pais possui 91 dados desconhecidos.

# %% [markdown]
# - Conta quantos valores estão presentes (não nulos) na coluna parental_education_level do dataframe e exibe esse total em uma mensagem informando quantos dados conhecidos existem sobre a escolaridade dos pais.

# %%
valores_nulos = (df["parental_education_level"].notnull().sum())
print(f"A coluna de escolaridade dos pais possui {valores_nulos} dados conhecidos.")
# Out:
# A coluna de escolaridade dos pais possui 909 dados conhecidos.

# %% [markdown]
# - Retorna todos os valores únicos (sem repetição) presentes na coluna parental_education_level do dataframe, mostrando quais categorias distintas de escolaridade dos pais aparecem nos dados.

# %%
df["parental_education_level"].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %% [markdown]
# - Conta quantos valores únicos (distintos) existem na coluna parental_education_level do dataframe, retornando o número total de categorias diferentes de escolaridade dos pais presentes nos dados.

# %%
df["parental_education_level"].nunique()
# Out:
# 3

# %% [markdown]
# -  Cria um filtro que identifica as linhas em que a coluna parental_education_level está nula, e em seguida exibe apenas as linhas do dataframe onde essa informação não foi preenchida.

# %%
filtro_nao_preenchido = df["parental_education_level"].isna()
df[filtro_nao_preenchido]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10       S1010   19  Female                  4.6                 3.7
# 33       S1033   18  Female                  4.0                 0.9
# 47       S1047   23  Female                  2.5                 2.9
# 74       S1074   21  Female                  2.3                 1.0
# 93       S1093   22    Male                  4.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 921      S1921   23  Female                  4.4                 2.7
# 925      S1925   19   Other                  1.7                 2.9
# 939      S1939   18  Female                  4.7                 3.2
# 945      S1945   23    Male                  6.0                 2.9
# 967      S1967   22    Male                  5.2                 4.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# - Substitui os valores nulos da coluna parental_education_level pelo texto "Desconhecido" e, em seguida, exibe um resumo geral do dataframe, incluindo tipos de dados e quantidade de valores preenchidos em cada coluna.

# %%
# o comando fillna preenche os valores nulos.
df["parental_education_level"] = df["parental_education_level"].fillna("Desconhecido")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
# ...

# %% [markdown]
# - Conta e retorna quantos valores estão ausentes (nulos) na coluna parental_education_level do dataframe.

# %%
df["parental_education_level"].isna().sum()
# Out:
# np.int64(0)

# %%
df["parental_education_level"].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Desconhecido'], dtype=object)

# %%
df["parental_education_level"].nunique()
# Out:
# 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
# ...

# %%
colunas = [
    "age",
    "study_hours_per_day",
    "social_media_hours",
    "netflix_hours",
    "attendance_percentage",
    "sleep_hours",
    "exercise_frequency",
    "mental_health_rating",
    "exam_score"
    ]

# %%
sns.heatmap(data=df[colunas].corr(),annot=True,cmap="coolwarm",fmt=".2f");

# %% [markdown]
# ## Resultados

# %%
filtro_horas_altas = df["study_hours_per_day"] >= 5



filtro_horas_baixas = df["study_hours_per_day"] < 5

# %%
media_pessoas_estudam_muito = df[filtro_horas_altas]["exam_score"].mean()

media_pessoas_estudam_pouco = df[filtro_horas_baixas]["exam_score"].mean()

print(media_pessoas_estudam_muito)
print (media_pessoas_estudam_pouco)

print(f"A média das pessoas que estudam muito é de: {media_pessoas_estudam_muito:.2f}")
print(f"A media das pessoas que estudam menos é de:{media_pessoas_estudam_pouco:.2f}")
# Out:
# 90.30059880239521
# 65.45174069627852
# A média das pessoas que estudam muito é de: 90.30
# A media das pessoas que estudam menos é de:65.45

# %%
grafico = sns.lmplot(data=df,x="study_hours_per_day",y="exam_score");
grafico.set_xlabels("Quantidade de horas de estudo por dia");
grafico.set_ylabels("Nota do exame");

# %%
sns.lmplot(data=df,x="netflix_hours",y="exam_score");

# %%
sns.lmplot(data=df,x="age",y="exam_score");

# %%
sns.lmplot(data=df,x="mental_health_rating",y="exam_score");

# %%
df.to_csv("dataset_studante_tratado.csv")

# %% [markdown]
# ## Parte 1
#
# - Faça as três perguntas abaixo, na ordem, para a mesma IA. Observe como a resposta melhora a cada versão.
#
# - Respostas da: https://chat.maritaca.ai/

# %% [markdown]
# - **Pergunta 1 (apenas a pergunta):** Qual hábito mais influencia a nota dos alunos?

# %% [markdown]
# 🏆 O hábito que mais influencia a nota: Horas de estudo por dia
# A evidência é contundente:
#
# Métrica	Valor	Interpretação
# Correlação (Pearson)	r = 0,83	⭐ Correlação muito forte (escala de 0 a 1)
# Coeficiente de regressão	+9,6 pontos por hora/dia	Cada hora extra de estudo eleva a nota em ~9,6 pontos
# % da variância explicada	~68% isoladamente	Sozinho, explica quase 70% das diferenças de nota
# Para dimensionar o impacto:
# yaml
#
# Copiar
# Estudante A: 2h de estudo/dia  ———  nota estimada: ~26 pontos
# Estudante B: 6h de estudo/dia  ———  nota estimada: ~98 pontos
#                                    DIFERENÇA: 72 pontos
# Comparação com outros hábitos:
#
# Hábito	Correlação	Impacto por unidade
# 🥇 Estudo/dia	+0,83	+9,6 pontos/hora
# 🥈 Saúde mental	+0,32	+1,9 pontos (por ponto no rating)
# 🥉 Exercício	+0,16	+1,4 pontos (por unidade de frequência)
# Redes sociais (negativo)	−0,17	−2,6 pontos/hora
# Netflix (negativo)	−0,17	−2,3 pontos/hora
# Sono	+0,12	+2,0 pontos/hora
# Visualização: quanto mais se estuda, maior a nota
# Conclusão: Nenhum outro hábito chega perto. O tempo dedicado ao estudo é ~5× mais influente que o segundo fator (saúde mental). Reduzir redes sociais/Netflix ajuda, mas o efeito é modesto (−2,5 pontos por hora). O verdadeiro divisor de águas é simples: sentar e estudar.

# %% [markdown]
# - **Pergunta 2 (a pergunta com contexto):**  Esta base tem 1000 alunos, com hábitos (horas de estudo, sono, redes sociais, exercício) e a nota final no exame (exam_score). Analise quais hábitos mais influenciam a nota e mostre os números que comprovam.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Análise: Quais hábitos mais influenciam a nota no exame?
# A base tem 1.000 alunos e 5 hábitos candidatos. A análise combinou correlação de Pearson, regressão linear múltipla e análise por faixas. Todos os resultados estatísticos são significativos (p < 0,0001).
#
# 📊 Matriz de Correlação (Pearson) com a nota
#
# Hábito	Correlação	Interpretação
# ⬆️ Horas de estudo/dia	+0,83	Muito forte — principal motor da nota
# ⬇️ Horas em redes sociais	−0,17	Moderada negativa
# ⬇️ Horas em Netflix	−0,17	Moderada negativa
# ⬆️ Frequência de exercício	+0,16	Fraca positiva
# ⬆️ Horas de sono	+0,12	Fraca positiva
# O estudo sozinho já explica ~68% da variância da nota (0,83²). Os demais hábitos ficam na casa de 2-3% cada.
#
# 🧪 Regressão linear múltipla (todos os hábitos juntos)
# O modelo explica R² = 0,79 — ou seja, 79% da variação nas notas é capturada por esses 5 hábitos.
#
#
# Hábito	Coeficiente	Interpretação prática
# Horas de estudo/dia	+9,58	Cada hora a mais de estudo → +9,6 pontos na nota
# Horas em redes sociais	−2,57	Cada hora a mais → −2,6 pontos
# Horas em Netflix	−2,24	Cada hora a mais → −2,2 pontos
# Frequência de exercício	+1,45	Cada sessão semanal a mais → +1,4 pontos
# Horas de sono	+1,99	Cada hora a mais de sono → +2,0 pontos
# O coeficiente do estudo (9,6) é 4 a 6 vezes maior que qualquer outro — ele domina inequivocamente.
#
# 🔍 Evidência 1: Efeito dose-resposta do estudo
#
# Faixa de estudo diário	Nota média	Δ vs anterior
# 0–2h	47,5	—
# 2–4h	66,0	+18,4
# 4–6h	82,1	+16,0
# 6–8h	97,7	+15,6
# A relação é quase linear: a cada bloco de 2h adicionais, a nota sobe ~16 pontos, até o teto de ~100.
#
# 🔍 Evidência 2: Efeito negativo das redes sociais
#
# Faixa de uso de redes sociais	Nota média
# 0–1h/dia	73,5
# 1–2h	72,3
# 2–3h	70,1
# 3–4h	66,1
# 4–5h	64,7
# 6+h	60,6
# Quem passa 6+ horas em redes sociais perde ~13 pontos em relação a quem usa até 1h.

# %% [markdown]
# - Pergunta 3 (contexto, persona e formato de resposta): Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.

# %% [markdown]
# Os 3 hábitos que mais impactam o desempenho dos alunos
# Com base na análise de 1.000 estudantes, cruzei 12 hábitos de vida e estudo com a nota final em exames. Três fatores se destacam com evidência estatística robusta (p < 0,0001 em todos os casos):
#
# 🥇 1. Horas de estudo por dia — o hábito mais decisivo
#
# Grupo	Média na prova	Nº de alunos
# ≥ 4 horas/dia	83,5	385
# < 2 horas/dia	45,6	133
# ➡️ Diferença: 37,9 pontos (quase 4x maior que qualquer outro hábito)
# A correlação entre horas de estudo e nota é r = 0,83 — uma das relações mais fortes que se pode observar em dados educacionais. Na regressão múltipla (controlando idade, gênero e demais hábitos), cada hora adicional de estudo por dia acrescenta ~9,6 pontos à nota final.
#
# Tradução para a prática: um aluno que passa de 1h para 3h de estudo diário tem potencial para ganhar ~19 pontos na nota — o suficiente para sair de uma faixa de risco para um desempenho sólido.
#
# 🥈 2. Horas em redes sociais — impacto negativo consistente
#
# Grupo	Média na prova	Nº de alunos
# < 1 hora/dia	74,1	98
# ≥ 3 horas/dia	66,2	364
# ➡️ Penalidade: −7,9 pontos para quem usa redes sociais intensamente
# A correlação é r = −0,17 (negativa e estatisticamente significativa). Na regressão, cada hora extra em redes sociais reduz a nota em ~2,6 pontos. O dado preocupante: 36% dos alunos (364 de 1.000) ficam 3h ou mais por dia nessas plataformas.
#
# **Implicação**: se um estudante que passa 4h/dia em redes sociais reduzir para 1h, o ganho potencial é de ~7 a 8 pontos na nota — sem mudar mais nada na rotina.
#
# 🥉 3. Horas de Netflix/streaming — efeito negativo equivalente
#
# Grupo	Média na prova	Nº de alunos
# < 1 hora/dia	74,1	238
# ≥ 3 horas/dia	65,9	160
# ➡️ Penalidade: −8,2 pontos para consumo pesado de streaming
# Correlação r = −0,17, praticamente idêntica à das redes sociais. Na regressão, cada hora extra de Netflix reduz a nota em ~2,2 pontos. Somando redes sociais + Netflix, um aluno heavy user pode estar perdendo 15 a 20 pontos apenas com tempo de tela passivo.
#
# 📊 Resumo comparativo
#
# Hábito	Direção	Impacto (pontos)	Correlação	Significância
# 📚 Horas de estudo	Positivo	+37,9 (entre extremos)	+0,83	p < 0,0001
# 📱 Redes sociais	Negativo	−7,9 (entre extremos)	−0,17	p < 0,0001
# 🎬 Netflix/streaming	Negativo	−8,2 (entre extremos)	−0,17	p < 0,0001
# 🏃 Exercício físico	Positivo	+1,4 por dia/semana	+0,16	p < 0,0001
# 😴 Sono	Positivo	+2,9 (entre extremos, NS)	+0,12	p = 0,13
# NS = não significativo na comparação entre extremos, embora a correlação geral seja positiva.
#
# 💡 Recomendações para a direção escolar
# Programa de mentoria de estudo estruturado — dado que a hora de estudo é o fator mais poderoso (9,6 pontos por hora), investir em orientação de técnicas de estudo e criação de rotina tem o maior ROI. Um ganho de 2h/dia na média da turma equivale a ~20 pontos de elevação potencial na nota.
#
# Campanha de conscientização sobre tempo de tela — redes sociais + Netflix consomem em média 4–5 horas/dia dos alunos com maior prejuízo. Uma redução de 50% nesse tempo liberaria ~2h/dia que, se convertidas em estudo, gerariam um duplo benefício (menos penalidade + mais ganho).
#
# Monitoramento individualizado — os 364 alunos que passam ≥3h/dia em redes sociais têm nota média de 66,2, contra 74,1 dos moderados. Identificar e acompanhar esses estudantes pode render ganhos rápidos.
#
# O efeito de trabalho de meio período, participação em atividades extracurriculares e qualidade da dieta mostrou impacto estatisticamente desprezível nesta amostra — sugerindo que, no curto prazo, o foco deve estar no tripé: estudar mais, navegar menos, assistir menos.

# %% [markdown]
# ## Parte 2
#
# - O heatmap que fizemos usou apenas as colunas numéricas. A base também tem colunas de texto que o código não analisou. Use o estilo da Pergunta 3 (com contexto e persona) para investigar pelo menos três das perguntas abaixo:

# %% [markdown]
# - **Pergunta 1:** A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo.

# %% [markdown]
# **Qualidade da Dieta vs. Nota do Exame**
#
# **Média por grupo**
#
# Qualidade da Dieta	Nota Média	Alunos	Desvio Padrão
# Poor (Ruim)	68,13	185	17,06
# Fair (Razoável)	70,43	437	16,65
# Good (Boa)	69,37	378	17,07
# A diferença entre os grupos é pequena — no máximo 2,3 pontos entre o grupo de pior e o de melhor dieta.
#
# Análise estatística
# Fiz uma ANOVA para testar se as diferenças entre os três grupos são estatisticamente significativas:
#
# ANOVA: F = 1,27, p = 0,28 → não significativo (p > 0,05)
# Nenhuma das comparações par a par atingiu significância estatística:
# Poor vs. Fair: p = 0,12
# Poor vs. Good: p = 0,42
# Fair vs. Good: p = 0,37
#
# **Visualização:**
#
# ![image.png](attachment:image.png)
#
# **Conclusão:**
#
# A qualidade da dieta, isoladamente, não faz diferença estatisticamente significativa na nota do exame neste dataset. Embora o grupo "Fair" tenha a maior média (70,43), as diferenças entre os três grupos estão dentro da variação aleatória — ou seja, não podemos afirmar com confiança que uma dieta melhor leva a notas melhores com base apenas nesta variável.
#
# Isso não significa que a dieta seja irrelevante para o desempenho acadêmico em geral; é possível que seu efeito apareça apenas quando combinada com outros fatores (como horas de sono, saúde mental, horas de estudo etc.). Uma análise multivariada poderia revelar interações que a comparação simples por grupo não captura. Quer que eu explore isso?

# %% [markdown]
# - **Pergunta 2:** Alunos com trabalho de meio período (part_time_job) vão pior nas notas?

# %% [markdown]
# **Trabalho de Meio Período vs. Notas: Análise dos Dados**
#
# **Resposta curta: não — a diferença é estatisticamente insignificante.** Alunos com trabalho de meio período não vão significativamente pior nas notas.
#
# ---
#
# **Estatísticas descritivas**
#
# Como os dados originais vieram todos juntos, foi preciso separar o que é o nome de cada coluna e o que são os valores correspondentes de cada grupo.
#
# Aqui está a sua tabela devidamente organizada e formatada em Markdown:
#
# | Grupo | Alunos | Média de Nota | Mediana | Desvio Padrão |
# | --- | --- | --- | --- | --- |
# | **Sem trabalho de meio período** | 785 | 69,8 | 70,6 | 17,0 |
# | **Com trabalho de meio período** | 215 | 68,7 | 69,2 | 16,6 |
#
# A diferença bruta é de apenas **~1,1 ponto** a menos para quem trabalha.
#
# ---
#
# **Teste estatístico (t-teste)**
#
# O teste t para diferença de médias entre os dois grupos resultou em:
#
# - t = −0,85, p = 0,39
#
# - Como p > 0,05, não rejeitamos a hipótese nula — ou seja, a diferença observada pode ser explicada pelo acaso.
#
# ---
#
# **Análise multivariada (regressão linear)**
#
# Para controlar possíveis fatores de confusão, rodei uma regressão com as seguintes variáveis de controle: horas de estudo, frequência nas aulas, horas de sono e escolaridade dos pais.
#
#
# **Variável**
#
# | Variável | Coeficiente | p-valor |
# | --- | --- | --- |
# | Trabalho de meio período | −0,008 | 0,99 |
# | Horas de estudo/dia | +9,52 | < 0,001 ✅ |
# | Frequência (%) | +0,12 | < 0,001 ✅ |
# | Horas de sono | +1,98 | < 0,001 ✅ |
# | Escolaridade dos pais | −0,17 | 0,61 |
#
# O coeficiente do trabalho de meio período é praticamente zero (−0,008) e o p-valor é 0,99 — confirmando que, **controlando por outros fatores**, ter um emprego de meio período **não tem efeito detectável nas notas.**
#
# ---
#
# **Visualização**
#
# ![image.png](attachment:image.png)
#
# Os boxplots mostram que as distribuições das notas são praticamente sobrepostas — a mediana, os quartis e os extremos são muito similares nos dois grupos.
#
# ---
#
# **Interpretação**
#
# Os dados sugerem que alunos que conciliam trabalho de meio período com estudos não sofrem prejuízo significativo nas notas. Isso pode indicar que:
#
# 1- Os alunos que trabalham conseguem gerenciar bem o tempo, compensando com maior eficiência nos estudos;
#
# 2- O trabalho de meio período pode até trazer benefícios não capturados (disciplina, maturidade, motivação financeira);
#
# 3- Os fatores que realmente importam para a nota são horas de estudo (coeficiente +9,5), frequência nas aulas (+0,12) e sono (+1,98).
#
# ⚠️ **Ressalva:** esta análise é observacional e baseada em correlação. Uma análise causal mais robusta exigiria métodos como pareamento (matching) ou experimentos naturais. Mas, com os dados disponíveis, **não há evidência de que o trabalho de meio período prejudique o desempenho acadêmico.**
#
# ---

# %% [markdown]
# **Pergunta 3:** A escolaridade dos pais (parental_education_level) tem relação com o desempenho?

# %% [markdown]
# # Análise de Correlação: Escolaridade dos Pais vs. Desempenho Escolar
#
# Com base na análise estatística do arquivo `dataset_studante_tratado.csv`, a escolaridade dos pais (**parental_education_level**) **não apresenta uma relação forte ou linear** com o desempenho dos alunos nos exames (**exam_score**).
#
# Tanto as médias quanto as medianas das notas permanecem muito próximas e distribuídas de forma semelhante entre as diferentes categorias.
#
# ---
#
# ### 📊 Resumo Estatístico
#
# | Escolaridade dos Pais | Quantidade de Alunos | Média da Nota | Mediana da Nota | Desvio Padrão |
# | :--- | :---: | :---: | :---: | :---: |
# | **Bachelor** (Bacharelado) | 350 | **70,27** | 71,70 | 17,29 |
# | **Desconhecido** | 91 | **70,03** | 71,00 | 16,56 |
# | **High School** (Ensino Médio) | 392 | **69,55** | 69,95 | 16,83 |
# | **Master** (Mestrado) | 167 | **68,09** | 66,80 | 16,40 |
#
# ---
#
# ### 🔍 Principais Conclusões
#
# * **Equilíbrio entre os grupos:** Curiosamente, os filhos de pais com Mestrado (`Master`) têm uma média ligeiramente *menor* (68,09) do que os filhos de pais com Ensino Médio (69,55) ou Bacharelado (70,27). No entanto, essa diferença é estatisticamente muito sutil (cerca de 2 pontos), não indicando uma tendência real de impacto negativo.
# * **Variabilidade Constante:** O desvio padrão é praticamente idêntico em todos os grupos (por volta de 16-17 pontos). Isso significa que a dispersão das notas (alunos com desempenho excelente e alunos com desempenho baixo) acontece na mesma proporção, independentemente do nível de instrução dos pais.
# * **Fatores Externos:** Essa ausência de correlação direta sugere que o desempenho dos estudantes neste ecossistema é mais influenciado por variáveis individuais (como `study_hours_per_day` ou `attendance_percentage`) do que pelo histórico acadêmico familiar.
