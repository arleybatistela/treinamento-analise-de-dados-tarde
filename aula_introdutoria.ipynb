# %%
email = "aebatistela78gmail.com"
print(f"O meu email é: {email}")
# Out:
# O meu email é: aebatistela78gmail.com

# %%
idade = 47
print(f"A minha idade é, {idade} anos")
# Out:
# A minha idade é, 47 anos

# %%
nome = "Arley"
print(f"O seu nome é, {nome}")
# Out:
# O seu nome é,Arley

# %%
Desafio: Criar uma variável que armazena o nome, idade, email e profisão do usuário. Exibir as mensagens de forma personalizada.

# %%
print(f"O seu nome é {nome}")
# Out:
# O seu nome é Arley

# %%
#cCélula de variáveis
nome = "Arley"
print("O seu nome é",nome)
# Out:
# O seu nome é Arley

# %%
print("Treianmento de IA para análise de Dados")
# Out:
# Treianmento de IA para análise de Dados

# %%
print("Batistela")
# Out:
# Batistela

# %%
profissao = "Analista de Dados"
print(f"Minha profissão é: {profissao}")
# Out:
# Minha profissão é: Analista de Dados

# %%
#Comparadores
print(10>5)
# Out:
# True

# %%
#Comparador outra opção
comparador = 10 > 5 #Retorne True se for maior
print(comparador)
# Out:
# True

# %%
comparador = 10<5
print(comparador)
# Out:
# False

# %%
comparador = 5 < 10 #Retorne True de dor menor
print(comparador)
# Out:
# True

# %%
comparador = (10 != 5) #Retorne True se forem diferentes
print(comparador)
# Out:
# True

# %%
temperatura =  100
if temperatura > 100
    print("ALARME! O MOTOR ESTÁ FERVENDO")
else

# %%
Criar um script, que irá auxiliar os alunos do SENAI a saberem se devem ou não comprar um uniforme.
Cursos acima de 40 horas, necessitam de uniforme
- Power BI: 32 horas
- IA e Análise de Dados: 40 horas
- Eletricista Instalador: 160 horas

# %%
uniforme = 40
if uniforme > 40
    print("Comprar uniforme")
else
print("Não comprar uniforme")

Power BI = 32 < 40 # Não precida utilizar uniforme, porém precisa do crachá para acesso no SENAI
# Out:
#   Cell In[36], line 2
#     if uniforme > 40
#                     ^
# SyntaxError: expected ':'

# %%
power_bi = 32
ia_dados = 40
electric_inst = 160

# %%
if power_bi > 40:
    print()

# %%
Verificar a qualidade das notas de um aluno
Maior do que 9: Excelente
Maior do que 7: Boa
Maior do que 5: Regular
Abaixo de 5: Reprovado

# %%
#O comando input solicita a interação do usuário
nota = int(input("Digite a sua nota: "))
print(nota)
# Out:
# 3

# %%
if nota > 9:
    print("NOTA EXCELENTE")
elif nota > 7:
    print("NOTA BOA")
elif nota >5:
    print("NOTA REGULAR")
else:
    print("REPROVADO \n\tEsude Mais meu Caro Aluno!")
# Out:
# REPROVADO
# 	Esude Mais meu Caro Aluno!

# %%
#imput é para entrada de dados
#AAP de um banco virtual
nome_primario = input("Digite o seu nome_primario:")
print(f"Bem vindo {nome_primario}" )
# Out:
# Bem vindo joao

# %%
idade = int(input("Digite a sua idade:"))
print(idade)
print(type(idade))
# Out:
# 50
# <class 'int'>
