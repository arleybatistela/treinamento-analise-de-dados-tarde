# %%
#Estruturas de Dados
temperaturas = [30,35,39,40,42,45,38,37]
print(temperaturas)
# Out:
# [30, 35, 39, 40, 42, 45, 38, 37]

# %%
print(temperaturas[0])
# Out:
# 30

# %%
print(f"O Primeiro registro de temperatura foi de {temperaturas[0]} graus.")
# Out:
# O Primeiro registro de temperatura foi de 30 graus.]

# %%
temperaturas[0] = 35
print(temperaturas [0])
# Out:
# 35

# %%
temperaturas.append(50)
print(temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove(39)
print(temperaturas)
# Out:
# [35, 35, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove(temperaturas[0])
print(temperaturas)
# Out:
# [35, 40, 42, 45, 38, 37, 50]

# %%
#Criem uma lista e solicitem que o usuário insira informações (3 comandos input). Ao finalizar exibir a lista de compras
informacoes = []
item_um = input("Digite o primeiro item: ")
informacoes.append (item_um)
print(informacoes)

item_dois = input("Digite o segundo item:")
informacoes.append (item_dois)
print(informacoes)

item_tres = input("Digite o terceiro item: ")
informacoes.append (item_tres)
print(informacoes)
# Out:
# ['maca']
# ['maca', 'morango']
# ['maca', 'morango', 'melão']

# %% [markdown]
# ## Vscode
